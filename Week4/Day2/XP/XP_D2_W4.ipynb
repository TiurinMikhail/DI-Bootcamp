# %% [markdown]
# Exercise 1 : Identifying Data Types

# %% [markdown]
# A company’s financial reports stored in an Excel file. --  structured
# Photographs uploaded to a social media platform. -- unstructured
# A collection of news articles on a website. -- unstructured
# Inventory data in a relational database.-- structured
# Recorded interviews from a market research study. -- unstructured

# %% [markdown]
# Exercise 2 : Transformation Exercise

# %%
A series of blog posts about travel experiences.
NLP: We can made a table with the name of the author, date of the post and analyzing with AI make a score (from 1 to 5) 


Audio recordings of customer service calls.
NLP + voice to text transcription


Handwritten notes from a brainstorming session.
OCR method (Optical Character Recognition)

A video tutorial on cooking.

Video Transcription or annotation

# %% [markdown]
# Transaction records:
# ---------------------------------------------
# Categorization: Structured data
# Usage: Analyze transaction records to understand customer purchase behavior, popular products, sales trends over time, and seasonal variations. This information can be used for inventory management, pricing optimization, targeted marketing campaigns, and identifying opportunities for upselling or cross-selling.
#
# Customer feedback comments:
# --------------------------------------------
# Categorization: Unstructured data
# Usage: Apply sentiment analysis and text mining techniques to analyze customer feedback comments. Identify common themes, sentiment trends, and areas for improvement in products, services, or customer experiences. Use insights to address customer concerns, enhance product features, improve service quality, and tailor marketing strategies to better meet customer needs.
#
# Social media posts about your brand:
# ----------------------------------------------
# Categorization: Unstructured data
# Usage: Monitor social media platforms to gather insights into brand sentiment, customer engagement, and trends in customer preferences or interests. Analyze social media data to identify brand advocates, detect potential issues or complaints, and engage with customers in real-time. Use social listening tools to track mentions of the brand, competitor activity, and industry trends, enabling proactive reputation management and responsive marketing strategies.
#
# Employee work schedules:
# --------------------------
# Categorization: Structured data
# Usage: Utilize employee work schedule data for workforce management, scheduling optimization, and resource allocation. Analyze scheduling patterns to ensure adequate staffing levels during peak hours, optimize shift assignments based on employee availability and skills, and minimize labor costs while maintaining operational efficiency. Additionally, track employee attendance and performance metrics to identify training needs, recognize high-performing employees, and address any scheduling conflicts or compliance issues.

# %% [markdown]
# Exercise 4 : Synthetic Data Generation
# ----

# %%
from faker import Faker
import numpy as np
import pandas as pd

# %%
fake = Faker()

# %%
random_data = []
for _ in range(100):
    name = fake.name()
    address = fake.address()
    email = fake.email()
    age = np.random.randint(18,70)
    random_data.append((name, address, email,age))

# %%
df = pd.DataFrame(random_data,columns = ['Name','Address','Email','Age'])

# %%
df.head(10)
# Out:
#                Name                                            Address  \
# 0      Steven Mills             483 Keith Roads\nMaloneville, TX 88482
# 1      Craig Cooper                   Unit 0813 Box 4952\nDPO AA 82088
# 2        Mike Brown               9694 Jones Path\nRandytown, FM 66231
# 3       Mark Carter              1176 Cody Alley\nJamesburgh, WA 04405
# 4   Michele Johnson         88375 Robert Overpass\nYangmouth, VA 83924
# 5        Carl Nixon                   PSC 1000, Box 1036\nAPO AP 52199
# 6  Francis Curry MD    344 Kimberly Roads Apt. 400\nLouiston, KS 39547
# 7    Manuel Fuentes  6590 Denise Branch Apt. 032\nSouth Julie, WA 1...
# 8   Cassandra Ponce   515 Nathan Crest Apt. 130\nNicoleshire, AK 22052
# 9     Roberta Clark  86775 Gutierrez Mission Apt. 411\nJohnsonberg,...
#
#                       Email  Age
# 0      colton15@example.org   27
# 1   carneycindy@example.com   31
# 2    danielle60@example.net   65
# 3         hruiz@example.net   50
# ...

# %% [markdown]
# Exercise 6 : Simulation-Based Dataset Creation
# -----

# %% [markdown]
# Creating a simulation for traffic flow in a city involves several steps to ensure the accuracy and realism of the generated dataset. Here's an outline of the steps involved:
#
# Define the City Layout:
#
# Identify the road network, including highways, streets, intersections, and traffic signals.
# Determine the locations of key landmarks, such as residential areas, commercial districts, and industrial zones.
# Specify the speed limits, lane configurations, and traffic rules for different road segments.
# Model Vehicle Behavior:
#
# Choose a variety of vehicle types, such as cars, trucks, buses, bicycles, and pedestrians.
# Define parameters for each vehicle type, including acceleration, deceleration, maximum speed, and reaction time.
# Implement realistic driving behaviors, such as lane changing, following distances, and yielding to pedestrians.
# Simulate Traffic Conditions:
#
# Define the time frame for the simulation, including peak hours, off-peak hours, and weekends.
# Introduce variations in traffic density, congestion levels, and weather conditions based on the time of day and day of the week.
# Incorporate random events, such as accidents, road closures, and construction zones, to simulate real-world disruptions.
# Implement Traffic Signals and Controls:
#
# Place traffic signals at intersections and pedestrian crossings.
# Define signal timings, including green, yellow, and red phases, based on traffic flow and pedestrian activity.
# Model the effects of traffic signals on vehicle movement, including delays, queues, and signal coordination.
# Collect Data from the Simulation:
#
# Define metrics to measure traffic performance, such as vehicle count, average speed, travel time, and queue length.
# Specify the time intervals for data collection, such as every minute, every hour, or during peak periods.
# Record data on vehicle movements, traffic signal states, and any incidents or disruptions encountered during the simulation.
# Analyze and Interpret the Data:
#
# Use statistical analysis and visualization techniques to explore patterns and trends in the simulated traffic data.
# Identify areas of congestion, traffic bottlenecks, and safety hazards based on the collected data.
# Evaluate the effectiveness of different traffic management strategies, such as signal timing adjustments or lane configurations.
# Utilize the Simulated Dataset:
#
# Share the dataset with transportation engineers, urban planners, and policymakers to inform decision-making and infrastructure planning.
# Use the data to optimize traffic signal timings, road designs, and public transportation routes to improve traffic flow and reduce congestion.
# Test and validate traffic management algorithms and intelligent transportation systems (ITS) using the simulated dataset before deployment in real-world scenarios.
# In summary, creating a simulation for traffic flow involves modeling various aspects of urban transportation, collecting data on simulated traffic conditions, and using the dataset to analyze traffic patterns and inform decision-making in traffic management and urban planning.

# %%
import numpy as np

class Vehicle:
    def __init__(self, vehicle_type, speed, acceleration):
        self.vehicle_type = vehicle_type
        self.speed = speed
        self.acceleration = acceleration

class Road:
    def __init__(self, length, speed_limit):
        self.length = length
        self.speed_limit = speed_limit

class TrafficSimulation:
    def __init__(self, road_length, speed_limit):
        self.road = Road(road_length, speed_limit)
        self.vehicles = []

    def add_vehicle(self, vehicle):
        self.vehicles.append(vehicle)

    def move_vehicles(self):
        for vehicle in self.vehicles:
            vehicle.speed += vehicle.acceleration
            if vehicle.speed > self.road.speed_limit:
                vehicle.speed = self.road.speed_limit

    def collect_data(self):
        vehicle_count = len(self.vehicles)
        average_speed = np.mean([vehicle.speed for vehicle in self.vehicles])
        # You can collect more data here based on your specific requirements
        return vehicle_count, average_speed

# Example usage
simulation = TrafficSimulation(1000, 60)  # 1000m road with speed limit of 60 km/h

# Add vehicles to the simulation
car = Vehicle('car', 0, 2)  # Car starts at rest with acceleration of 2 m/s^2
simulation.add_vehicle(car)

# Run the simulation for a certain number of time steps
num_steps = 100
for _ in range(num_steps):
    simulation.move_vehicles()
    vehicle_count, average_speed = simulation.collect_data()
    print(f"Step: {_ + 1}, Vehicle Count: {vehicle_count}, Average Speed: {average_speed:.2f} m/s")
# Out:
# Step: 1, Vehicle Count: 1, Average Speed: 2.00 m/s
# Step: 2, Vehicle Count: 1, Average Speed: 4.00 m/s
# Step: 3, Vehicle Count: 1, Average Speed: 6.00 m/s
# Step: 4, Vehicle Count: 1, Average Speed: 8.00 m/s
# Step: 5, Vehicle Count: 1, Average Speed: 10.00 m/s
# Step: 6, Vehicle Count: 1, Average Speed: 12.00 m/s
# Step: 7, Vehicle Count: 1, Average Speed: 14.00 m/s
# Step: 8, Vehicle Count: 1, Average Speed: 16.00 m/s
# Step: 9, Vehicle Count: 1, Average Speed: 18.00 m/s
# Step: 10, Vehicle Count: 1, Average Speed: 20.00 m/s
# Step: 11, Vehicle Count: 1, Average Speed: 22.00 m/s
# Step: 12, Vehicle Count: 1, Average Speed: 24.00 m/s
# Step: 13, Vehicle Count: 1, Average Speed: 26.00 m/s
# Step: 14, Vehicle Count: 1, Average Speed: 28.00 m/s
# Step: 15, Vehicle Count: 1, Average Speed: 30.00 m/s
# Step: 16, Vehicle Count: 1, Average Speed: 32.00 m/s
# Step: 17, Vehicle Count: 1, Average Speed: 34.00 m/s
# Step: 18, Vehicle Count: 1, Average Speed: 36.00 m/s
# ...

# %%
from faker import Faker
import numpy as np

fake = Faker()

class Vehicle:
    def __init__(self, vehicle_type, speed, acceleration):
        self.vehicle_type = vehicle_type
        self.speed = speed
        self.acceleration = acceleration

class Road:
    def __init__(self, length, speed_limit):
        self.length = length
        self.speed_limit = speed_limit

class TrafficSimulation:
    def __init__(self, road_length, speed_limit):
        self.road = Road(road_length, speed_limit)
        self.vehicles = []

    def add_vehicle(self, vehicle):
        self.vehicles.append(vehicle)

    def move_vehicles(self):
        for vehicle in self.vehicles:
            vehicle.speed += vehicle.acceleration
            if vehicle.speed > self.road.speed_limit:
                vehicle.speed = self.road.speed_limit

    def collect_data(self):
        vehicle_count = len(self.vehicles)
        average_speed = np.mean([vehicle.speed for vehicle in self.vehicles])
        # You can collect more data here based on your specific requirements
        return vehicle_count, average_speed

# Example usage
simulation = TrafficSimulation(fake.random_int(min=500, max=2000), fake.random_int(min=40, max=80))  # Random road length and speed limit

# Add random vehicles to the simulation
num_vehicles = fake.random_int(min=5, max=20)
for _ in range(num_vehicles):
    vehicle_type = fake.random_element(elements=('car', 'truck', 'motorcycle'))
    speed = fake.random_int(min=0, max=simulation.road.speed_limit)
    acceleration = fake.random_int(min=0, max=5)
    vehicle = Vehicle(vehicle_type, speed, acceleration)
    simulation.add_vehicle(vehicle)

# Run the simulation for a certain number of time steps
num_steps = 100
for _ in range(num_steps):
    simulation.move_vehicles()
    vehicle_count, average_speed = simulation.collect_data()
    print(f"Step: {_ + 1}, Vehicle Count: {vehicle_count}, Average Speed: {average_speed:.2f} m/s")
# Out:
# Step: 1, Vehicle Count: 20, Average Speed: 30.75 m/s
# Step: 2, Vehicle Count: 20, Average Speed: 33.00 m/s
# Step: 3, Vehicle Count: 20, Average Speed: 35.20 m/s
# Step: 4, Vehicle Count: 20, Average Speed: 37.30 m/s
# Step: 5, Vehicle Count: 20, Average Speed: 39.30 m/s
# Step: 6, Vehicle Count: 20, Average Speed: 41.30 m/s
# Step: 7, Vehicle Count: 20, Average Speed: 43.30 m/s
# Step: 8, Vehicle Count: 20, Average Speed: 45.30 m/s
# Step: 9, Vehicle Count: 20, Average Speed: 46.95 m/s
# Step: 10, Vehicle Count: 20, Average Speed: 48.50 m/s
# Step: 11, Vehicle Count: 20, Average Speed: 49.90 m/s
# Step: 12, Vehicle Count: 20, Average Speed: 51.25 m/s
# Step: 13, Vehicle Count: 20, Average Speed: 52.60 m/s
# Step: 14, Vehicle Count: 20, Average Speed: 53.70 m/s
# Step: 15, Vehicle Count: 20, Average Speed: 54.75 m/s
# Step: 16, Vehicle Count: 20, Average Speed: 55.80 m/s
# Step: 17, Vehicle Count: 20, Average Speed: 56.75 m/s
# Step: 18, Vehicle Count: 20, Average Speed: 57.50 m/s
# ...

# %%
from faker import Faker
import numpy as np

fake = Faker()

class Vehicle:
    def __init__(self, vehicle_type, speed, acceleration):
        self.vehicle_type = vehicle_type
        self.speed = speed
        self.acceleration = acceleration

class Road:
    def __init__(self, length, speed_limit):
        self.length = length
        self.speed_limit = speed_limit

class TrafficSimulation:
    def __init__(self, road_length, speed_limit, peak_hours=False):
        self.road = Road(road_length, speed_limit)
        self.vehicles = []
        self.peak_hours = peak_hours

    def add_vehicle(self, vehicle):
        self.vehicles.append(vehicle)

    def move_vehicles(self):
        for vehicle in self.vehicles:
            vehicle.speed += vehicle.acceleration
            if vehicle.speed > self.road.speed_limit:
                vehicle.speed = self.road.speed_limit

    def collect_data(self):
        vehicle_count = len(self.vehicles)
        average_speed = np.mean([vehicle.speed for vehicle in self.vehicles])
        # You can collect more data here based on your specific requirements
        return vehicle_count, average_speed

    def simulate_traffic(self, num_steps):
        for step in range(num_steps):
            # Adjust traffic conditions for peak hours
            if self.peak_hours and 7 <= step <= 9:
                num_vehicles = fake.random_int(min=20, max=50)
                max_speed = self.road.speed_limit + 20
            else:
                num_vehicles = fake.random_int(min=5, max=20)
                max_speed = self.road.speed_limit

            # Add random vehicles to the simulation
            for _ in range(num_vehicles):
                vehicle_type = fake.random_element(elements=('car', 'truck', 'motorcycle'))
                speed = fake.random_int(min=0, max=max_speed)
                acceleration = fake.random_int(min=0, max=5)
                vehicle = Vehicle(vehicle_type, speed, acceleration)
                self.add_vehicle(vehicle)

            # Move vehicles and collect data
            self.move_vehicles()
            vehicle_count, average_speed = self.collect_data()
            print(f"Step: {step + 1}, Vehicle Count: {vehicle_count}, Average Speed: {average_speed:.2f} m/s")

# Example usage
simulation = TrafficSimulation(fake.random_int(min=500, max=2000), fake.random_int(min=40, max=100), peak_hours=True)
simulation.simulate_traffic(num_steps=100)
# Out:
# Step: 1, Vehicle Count: 10, Average Speed: 27.20 m/s
# Step: 2, Vehicle Count: 29, Average Speed: 27.10 m/s
# Step: 3, Vehicle Count: 36, Average Speed: 29.92 m/s
# Step: 4, Vehicle Count: 42, Average Speed: 31.12 m/s
# Step: 5, Vehicle Count: 51, Average Speed: 31.80 m/s
# Step: 6, Vehicle Count: 63, Average Speed: 33.59 m/s
# Step: 7, Vehicle Count: 83, Average Speed: 33.59 m/s
# Step: 8, Vehicle Count: 111, Average Speed: 35.44 m/s
# Step: 9, Vehicle Count: 161, Average Speed: 37.75 m/s
# Step: 10, Vehicle Count: 204, Average Speed: 39.74 m/s
# Step: 11, Vehicle Count: 212, Average Speed: 40.67 m/s
# Step: 12, Vehicle Count: 232, Average Speed: 40.52 m/s
# Step: 13, Vehicle Count: 238, Average Speed: 41.45 m/s
# Step: 14, Vehicle Count: 244, Average Speed: 42.46 m/s
# Step: 15, Vehicle Count: 249, Average Speed: 43.10 m/s
# Step: 16, Vehicle Count: 254, Average Speed: 43.91 m/s
# Step: 17, Vehicle Count: 260, Average Speed: 44.68 m/s
# ...
